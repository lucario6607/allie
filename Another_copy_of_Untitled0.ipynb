# %% [markdown]
# <a href="https://colab.research.google.com/github/lucario6607/allie/blob/master/Another_copy_of_Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !sudo apt-get install ninja-build

# !pip3 install meson

# !git clone --recurse-submodules -b release/0.31 https://github.com/LeelaChessZero/lc0.git

# !cd lc0 && rm -rf build

# !cd lc0 && meson build --buildtype release -Db_lto=true -Dgtest=false -Dblas=false -Dopencl=false -Dcudnn=false

# !cd lc0/build && ninja
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following NEW packages will be installed:
#   ninja-build
# 0 upgraded, 1 newly installed, 0 to remove and 49 not upgraded.
# Need to get 111 kB of archives.
# After this operation, 358 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/universe amd64 ninja-build amd64 1.10.1-1 [111 kB]
# Fetched 111 kB in 0s (274 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78, <> line 1.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package ninja-build.
# (Reading database ... 123630 files and directories currently installed.)
# Preparing to unpack .../ninja-build_1.10.1-1_amd64.deb ...
# Unpacking ninja-build (1.10.1-1) ...
# Setting up ninja-build (1.10.1-1) ...
# Processing triggers for man-db (2.10.2-1) ...
# Collecting meson
#   Downloading meson-1.6.0-py3-none-any.whl.metadata (1.8 kB)
# Downloading meson-1.6.0-py3-none-any.whl (973 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 973.9/973.9 kB 18.7 MB/s eta 0:00:00
# Installing collected packages: meson
# Successfully installed meson-1.6.0
# Cloning into 'lc0'...
# remote: Enumerating objects: 11636, done.
# remote: Counting objects: 100% (276/276), done.
# remote: Compressing objects: 100% (193/193), done.
# remote: Total 11636 (delta 167), reused 161 (delta 83), pack-reused 11360 (from 1)
# Receiving objects: 100% (11636/11636), 38.98 MiB | 18.45 MiB/s, done.
# Resolving deltas: 100% (8332/8332), done.
# Submodule 'libs/lczero-common' (https://github.com/LeelaChessZero/lczero-common.git) registered for path 'libs/lczero-common'
# Cloning into '/content/lc0/libs/lczero-common'...
# remote: Enumerating objects: 173, done.
# remote: Counting objects: 100% (33/33), done.
# remote: Compressing objects: 100% (20/20), done.
# remote: Total 173 (delta 7), reused 28 (delta 5), pack-reused 140 (from 1)
# Receiving objects: 100% (173/173), 36.06 KiB | 595.00 KiB/s, done.
# Resolving deltas: 100% (51/51), done.
# Submodule path 'libs/lczero-common': checked out '55e1b382efadd57903e37f2a2e29caef3ea85799'
# The Meson build system
# Version: 1.6.0
# Source dir: /content/lc0
# Build dir: /content/lc0/build
# Build type: native build
# Project name: lc0
# Project version: undefined
# C++ compiler for the host machine: c++ (gcc 11.4.0 "c++ (Ubuntu 11.4.0-1ubuntu1~22.04) 11.4.0")
# C++ linker for the host machine: c++ ld.bfd 2.38
# Host machine cpu family: x86_64
# Host machine cpu: x86_64
# Has header "optional" : YES
# Has header "string_view" : YES
# Has header "charconv" : YES
# Compiler for C++ supports arguments -march=native: YES
# Program scripts/compile_proto.py found: YES (/content/lc0/scripts/compile_proto.py)
# Program git found: YES (/usr/bin/git)
# Configuring build_id.h using configuration
# Run-time dependency threads found: YES
# Library dl found: YES
# Found pkg-config: YES (/usr/bin/pkg-config) 1.8.0
# Found CMake: /usr/local/bin/cmake (3.30.5)
# Run-time dependency tensorflow_cc found: NO (tried pkgconfig and cmake)
# Run-time dependency accelerate found: NO (tried pkgconfig and cmake)
# Library mkl_rt found: YES
# Library dnnl found: NO
# Library openblas.dll found: NO
# Library openblas found: YES
# Library OpenCL found: YES
# Run-time dependency opencl found: NO
# Has header "CL/opencl.h" : YES
# Library cublas found: YES
# Library cudnn found: YES
# Library cudart found: YES
# Program nvcc found: YES (/usr/local/cuda/bin/nvcc)
# Run-time dependency appleframeworks found: NO (tried framework)
# Run-time dependency zlib found: YES 1.2.11
# WARNING: find_library('libatomic') starting in "lib" only works by accident and is not portable
# Library libatomic found: YES
# Build targets in project: 3
#
# lc0 undefined
#
#   User defined options
#     b_lto    : true
#     blas     : false
#     buildtype: release
#     cudnn    : false
#     gtest    : false
#     opencl   : false
#
# Found ninja-1.10.1 at /usr/bin/ninja
# WARNING: Running the setup command as `meson [options]` instead of `meson setup [options]` is ambiguous and deprecated.
# [72/72] Linking target lc0
# lto-wrapper: warning: using serial compilation of 38 LTRANS jobs

# %%
# !wget https://github.com/CallOn84/LeelaNets/raw/refs/heads/main/Nets/Elite%20Leela/EliteLeela.pb.gz
# Out:
# --2024-11-24 16:46:22--  https://github.com/CallOn84/LeelaNets/raw/refs/heads/main/Nets/Elite%20Leela/EliteLeela.pb.gz
# Resolving github.com (github.com)... 140.82.112.3
# Connecting to github.com (github.com)|140.82.112.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/CallOn84/LeelaNets/refs/heads/main/Nets/Elite%20Leela/EliteLeela.pb.gz [following]
# --2024-11-24 16:46:23--  https://raw.githubusercontent.com/CallOn84/LeelaNets/refs/heads/main/Nets/Elite%20Leela/EliteLeela.pb.gz
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 6551855 (6.2M) [application/octet-stream]
# Saving to: ‘EliteLeela.pb.gz’
#
# EliteLeela.pb.gz    100%[===================>]   6.25M  --.-KB/s    in 0.06s
#
# 2024-11-24 16:46:23 (100 MB/s) - ‘EliteLeela.pb.gz’ saved [6551855/6551855]

# %%
pip install chess
# Out:
# Collecting chess
#   Downloading chess-1.11.1.tar.gz (156 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 156.5/156.5 kB 5.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: chess
#   Building wheel for chess (setup.py) ... done
#   Created wheel for chess: filename=chess-1.11.1-py3-none-any.whl size=148497 sha256=acb967c777bee2d20d59fa6a9029a0302c5820313d8d3725b59a5c04807de17c
#   Stored in directory: /root/.cache/pip/wheels/2e/2d/23/1bfc95db984ed3ecbf6764167dc7526d0ab521cf9a9852544e
# Successfully built chess
# Installing collected packages: chess
# Successfully installed chess-1.11.1

# %%
import json
import os
import sys
import argparse
import chess
import chess.engine
import chess.pgn
import datetime

config_file = "config_v1.json"

if not os.path.exists(config_file):
    print(f"Configuration file {config_file} does not exist.")
    sys.exit(1)

with open(config_file, 'r') as f:
    config = json.load(f)

# Extract variables from config
lc0_path = config['lc0_path']
white_net = config['white_net']
black_net = config['black_net']
num_games = config['num_games']
pgn_file_name = config['pgn_file_name']
use_opening_book = config['use_opening_book']
opening_book = config.get('opening_book', '')

engine1_options = config['engine1_options']
engine2_options = config['engine2_options']

depth_limit_w_nodes = config['depth_limit_w']
depth_limit_b_nodes = config['depth_limit_b']


# Set up the opening book or starting FENs
if use_opening_book:
    if not os.path.exists(opening_book):
        print(f"Opening book file {opening_book} does not exist.")
        sys.exit(1)
    with open(opening_book, 'r') as f:
        fens = [line.strip() for line in f if line.strip()]
else:
    fixed_start_fen = config.get('fixed_start_fen', chess.STARTING_FEN)
    fens = [fixed_start_fen]

# Replace 'white_net' and 'black_net' placeholders in engine options
def replace_net_paths(options):
    for key, value in options.items():
        if value == 'white_net':
            options[key] = white_net
        elif value == 'black_net':
            options[key] = black_net

replace_net_paths(engine1_options)
replace_net_paths(engine2_options)

# Initialize engines
engine1 = chess.engine.SimpleEngine.popen_uci(lc0_path)
engine2 = chess.engine.SimpleEngine.popen_uci(lc0_path)

# Configure engines
engine1.configure(engine1_options)
engine2.configure(engine2_options)

# Set node limits
depth_limit_w = chess.engine.Limit(nodes=depth_limit_w_nodes)
depth_limit_b = chess.engine.Limit(nodes=depth_limit_b_nodes)

# Open a PGN file to save the games
pgn_file = open(pgn_file_name, 'a')

# Load last saved progress, if available
if os.path.exists("progress.json"):
    with open("progress.json", "r") as f:
        progress_data = json.load(f)
        start_game = progress_data.get("game_number", 1)
else:
    start_game = 1

wins = 0
losses = 0
draws = 0

try:
    for game_number in range(start_game, num_games + 1):
        # Determine which FEN to use
        fen_index = (game_number - 1) % len(fens)
        start_fen = fens[fen_index]

        board = chess.Board(fen=start_fen)
        game = chess.pgn.Game()
        game.setup(board)
        node = game

        # Set game headers
        game.headers["Event"] = "Leela Queen Odds Training"
        game.headers["Site"] = "Local"
        game.headers["Date"] = datetime.datetime.now().strftime("%Y.%m.%d")
        game.headers["Round"] = str(game_number)
        game.headers["White"] = "LeelaZero_White"
        game.headers["Black"] = "LeelaZero_Black"

        try:
            while not board.is_game_over():
                if board.turn == chess.WHITE:
                    # White's turn
                    result = engine1.play(board, depth_limit_w)
                else:
                    # Black's turn
                    result = engine2.play(board, depth_limit_b)

                board.push(result.move)
                node = node.add_variation(result.move)
        except Exception as e:
            print(f"Exception during game {game_number}: {e}")
            # If an error occurs, skip to the next game
            continue

        # Game over, set the result
        game.headers["Result"] = board.result()

        match board.result():
            case '1-0':
                wins += 1
            case '0-1':
                losses += 1
            case _:
                draws += 1

        # Calculate total games
        total_games = wins + draws + losses

        # Save the game to the PGN file
        print(game, file=pgn_file, end="\n\n")

        # Upload the PGN file to Dropbox every 100 games
        if use_dropbox_upload and total_games % 100 == 0:
            # Close the PGN file to ensure all data is written
            pgn_file.close()

            try:
                # Dropbox upload code
                with open(pgn_file_name, "rb") as f:
                    dropbox_path = f"/{pgn_file_name}"
                    dbx.files_upload(f.read(), dropbox_path, mode=dropbox.files.WriteMode.overwrite)
                    print(f"Uploaded {pgn_file_name} to Dropbox.")
            except dropbox.exceptions.ApiError as e:
                print(f"Failed to upload to Dropbox: {e}")

            # Reopen the PGN file in append mode for further writing
            pgn_file = open(pgn_file_name, "a")

        # Calculate total points earned
        total_points = wins + 0.5 * draws

        # Calculate scoring percentage
        scoring_percentage = (total_points / total_games) * 100
        print(f"Total Games: {total_games}")
        print(f"{wins} Wins, {draws} Draws, {losses} Losses")
        print("Scoring Percentage: {:.2f}%".format(scoring_percentage))

        # Update progress
        with open("progress.json", "w") as f:
            json.dump({"game_number": game_number + 1}, f)

finally:
    # Quit engines
    engine1.quit()
    engine2.quit()
    # Close PGN file
    pgn_file.close()
# Out:
# WARNING:chess.engine:<UciProtocol (pid=12010)>: stderr >>        _
# WARNING:chess.engine:<UciProtocol (pid=12010)>: stderr >> |   _ | |
# WARNING:chess.engine:<UciProtocol (pid=12010)>: stderr >> |_ |_ |_| v0.31.2 built Nov 24 2024
# WARNING:chess.engine:<UciProtocol (pid=12018)>: stderr >>        _
# WARNING:chess.engine:<UciProtocol (pid=12018)>: stderr >> |   _ | |
# WARNING:chess.engine:<UciProtocol (pid=12018)>: stderr >> |_ |_ |_| v0.31.2 built Nov 24 2024
# WARNING:chess.engine:<UciProtocol (pid=12010)>: stderr >> Loading weights file from: lro_v1.pb.gz
# WARNING:chess.engine:<UciProtocol (pid=12010)>: stderr >> Creating backend [cuda-auto]...
# WARNING:chess.engine:<UciProtocol (pid=12010)>: stderr >> Switching to [cuda-fp16]...
# WARNING:chess.engine:<UciProtocol (pid=12010)>: stderr >> CUDA Runtime version: 12.2.0
# WARNING:chess.engine:<UciProtocol (pid=12010)>: stderr >> Latest version of CUDA supported by the driver: 12.2.0
# WARNING:chess.engine:<UciProtocol (pid=12010)>: stderr >> GPU: Tesla T4
# WARNING:chess.engine:<UciProtocol (pid=12010)>: stderr >> GPU memory: 14.7481 Gb
# WARNING:chess.engine:<UciProtocol (pid=12010)>: stderr >> GPU clock frequency: 1590 MHz
# WARNING:chess.engine:<UciProtocol (pid=12010)>: stderr >> GPU compute capability: 7.5
# WARNING:chess.engine:<UciProtocol (pid=12010)>: stderr >> L2 cache capacity: 4194304
# WARNING:chess.engine:<UciProtocol (pid=12018)>: stderr >> Loading weights file from: EliteLeela.pb.gz
# WARNING:chess.engine:<UciProtocol (pid=12018)>: stderr >> Creating backend [cuda-auto]...
# WARNING:chess.engine:<UciProtocol (pid=12018)>: stderr >> Switching to [cuda-fp16]...
# WARNING:chess.engine:<UciProtocol (pid=12018)>: stderr >> CUDA Runtime version: 12.2.0
# WARNING:chess.engine:<UciProtocol (pid=12018)>: stderr >> Latest version of CUDA supported by the driver: 12.2.0
# WARNING:chess.engine:<UciProtocol (pid=12018)>: stderr >> GPU: Tesla T4
# WARNING:chess.engine:<UciProtocol (pid=12018)>: stderr >> GPU memory: 14.7481 Gb
# WARNING:chess.engine:<UciProtocol (pid=12018)>: stderr >> GPU clock frequency: 1590 MHz
# WARNING:chess.engine:<UciProtocol (pid=12018)>: stderr >> GPU compute capability: 7.5
# WARNING:chess.engine:<UciProtocol (pid=12018)>: stderr >> L2 cache capacity: 4194304
# Total Games: 1
# 1 Wins, 0 Draws, 0 Losses
# Scoring Percentage: 100.00%
# Total Games: 2
# 2 Wins, 0 Draws, 0 Losses
# Scoring Percentage: 100.00%
# Total Games: 3
# 3 Wins, 0 Draws, 0 Losses
# Scoring Percentage: 100.00%
# Total Games: 4
# 3 Wins, 0 Draws, 1 Losses
# Scoring Percentage: 75.00%
# Total Games: 5
# 3 Wins, 0 Draws, 2 Losses
# Scoring Percentage: 60.00%
# Total Games: 6
# 3 Wins, 0 Draws, 3 Losses
# Scoring Percentage: 50.00%
# Total Games: 7
# 3 Wins, 1 Draws, 3 Losses
# Scoring Percentage: 50.00%
# Total Games: 8
# 4 Wins, 1 Draws, 3 Losses
# Scoring Percentage: 56.25%
# Total Games: 9
# 5 Wins, 1 Draws, 3 Losses
# Scoring Percentage: 61.11%
# Total Games: 10
# 5 Wins, 1 Draws, 4 Losses
# Scoring Percentage: 55.00%
# Total Games: 11
# 5 Wins, 2 Draws, 4 Losses
# Scoring Percentage: 54.55%
# Total Games: 12
# 5 Wins, 3 Draws, 4 Losses
# Scoring Percentage: 54.17%
# Total Games: 13
# 6 Wins, 3 Draws, 4 Losses
# Scoring Percentage: 57.69%
# Total Games: 14
# 6 Wins, 4 Draws, 4 Losses
# Scoring Percentage: 57.14%
# Total Games: 15
# 6 Wins, 4 Draws, 5 Losses
# Scoring Percentage: 53.33%
# Total Games: 16
# 7 Wins, 4 Draws, 5 Losses
# Scoring Percentage: 56.25%
# Total Games: 17
# 8 Wins, 4 Draws, 5 Losses
# Scoring Percentage: 58.82%
# Total Games: 18
# 8 Wins, 5 Draws, 5 Losses
# Scoring Percentage: 58.33%
# Total Games: 19
# 8 Wins, 6 Draws, 5 Losses
# Scoring Percentage: 57.89%
# Total Games: 20
# 8 Wins, 7 Draws, 5 Losses
# Scoring Percentage: 57.50%
# Total Games: 21
# 9 Wins, 7 Draws, 5 Losses
# Scoring Percentage: 59.52%
# Total Games: 22
# 9 Wins, 7 Draws, 6 Losses
# Scoring Percentage: 56.82%
# Total Games: 23
# 9 Wins, 7 Draws, 7 Losses
# Scoring Percentage: 54.35%
# Total Games: 24
# 9 Wins, 8 Draws, 7 Losses
# Scoring Percentage: 54.17%
# Total Games: 25
# 9 Wins, 9 Draws, 7 Losses
# Scoring Percentage: 54.00%
# Total Games: 26
# 9 Wins, 10 Draws, 7 Losses
# Scoring Percentage: 53.85%
# Total Games: 27
# 9 Wins, 11 Draws, 7 Losses
# Scoring Percentage: 53.70%
# Total Games: 28
# 10 Wins, 11 Draws, 7 Losses
# Scoring Percentage: 55.36%
# Total Games: 29
# 11 Wins, 11 Draws, 7 Losses
# Scoring Percentage: 56.90%
# Total Games: 30
# 11 Wins, 12 Draws, 7 Losses
# Scoring Percentage: 56.67%
# Total Games: 31
# 12 Wins, 12 Draws, 7 Losses
# Scoring Percentage: 58.06%
# Total Games: 32
# 12 Wins, 12 Draws, 8 Losses
# Scoring Percentage: 56.25%
# Total Games: 33
# 13 Wins, 12 Draws, 8 Losses
# Scoring Percentage: 57.58%
# Total Games: 34
# 14 Wins, 12 Draws, 8 Losses
# Scoring Percentage: 58.82%
# Total Games: 35
# 14 Wins, 13 Draws, 8 Losses
# Scoring Percentage: 58.57%
# Total Games: 36
# 14 Wins, 14 Draws, 8 Losses
# Scoring Percentage: 58.33%
# Total Games: 37
# 14 Wins, 14 Draws, 9 Losses
# Scoring Percentage: 56.76%
# Total Games: 38
# 15 Wins, 14 Draws, 9 Losses
# Scoring Percentage: 57.89%
# Total Games: 39
# 15 Wins, 15 Draws, 9 Losses
# Scoring Percentage: 57.69%
# Total Games: 40
# 16 Wins, 15 Draws, 9 Losses
# Scoring Percentage: 58.75%
# Total Games: 41
# 16 Wins, 16 Draws, 9 Losses
# Scoring Percentage: 58.54%
# Total Games: 42
# 16 Wins, 16 Draws, 10 Losses
# Scoring Percentage: 57.14%
# Total Games: 43
# 16 Wins, 16 Draws, 11 Losses
# Scoring Percentage: 55.81%
# Total Games: 44
# 17 Wins, 16 Draws, 11 Losses
# Scoring Percentage: 56.82%
# Total Games: 45
# 17 Wins, 16 Draws, 12 Losses
# Scoring Percentage: 55.56%
# Total Games: 46
# 18 Wins, 16 Draws, 12 Losses
# Scoring Percentage: 56.52%
# Total Games: 47
# 18 Wins, 16 Draws, 13 Losses
# Scoring Percentage: 55.32%
# Total Games: 48
# 18 Wins, 17 Draws, 13 Losses
# Scoring Percentage: 55.21%
# Total Games: 49
# 19 Wins, 17 Draws, 13 Losses
# Scoring Percentage: 56.12%
# Total Games: 50
# 19 Wins, 18 Draws, 13 Losses
# Scoring Percentage: 56.00%
# Total Games: 51
# 20 Wins, 18 Draws, 13 Losses
# Scoring Percentage: 56.86%
# Total Games: 52
# 20 Wins, 19 Draws, 13 Losses
# Scoring Percentage: 56.73%
# Total Games: 53
# 20 Wins, 19 Draws, 14 Losses
# Scoring Percentage: 55.66%
# Total Games: 54
# 21 Wins, 19 Draws, 14 Losses
# Scoring Percentage: 56.48%
# Total Games: 55
# 21 Wins, 19 Draws, 15 Losses
# Scoring Percentage: 55.45%
# Total Games: 56
# 21 Wins, 19 Draws, 16 Losses
# Scoring Percentage: 54.46%
# Total Games: 57
# 21 Wins, 19 Draws, 17 Losses
# Scoring Percentage: 53.51%
# Total Games: 58
# 21 Wins, 19 Draws, 18 Losses
# Scoring Percentage: 52.59%
# Total Games: 59
# 21 Wins, 20 Draws, 18 Losses
# Scoring Percentage: 52.54%
# Total Games: 60
# 21 Wins, 20 Draws, 19 Losses
# Scoring Percentage: 51.67%
# Total Games: 61
# 21 Wins, 20 Draws, 20 Losses
# Scoring Percentage: 50.82%
# Total Games: 62
# 22 Wins, 20 Draws, 20 Losses
# Scoring Percentage: 51.61%
# Total Games: 63
# 23 Wins, 20 Draws, 20 Losses
# Scoring Percentage: 52.38%
# Total Games: 64
# 24 Wins, 20 Draws, 20 Losses
# Scoring Percentage: 53.12%
# Total Games: 65
# 24 Wins, 20 Draws, 21 Losses
# Scoring Percentage: 52.31%
# Total Games: 66
# 24 Wins, 20 Draws, 22 Losses
# Scoring Percentage: 51.52%
# Total Games: 67
# 24 Wins, 20 Draws, 23 Losses
# Scoring Percentage: 50.75%
# Total Games: 68
# 25 Wins, 20 Draws, 23 Losses
# Scoring Percentage: 51.47%
# Total Games: 69
# 25 Wins, 20 Draws, 24 Losses
# Scoring Percentage: 50.72%
# Total Games: 70
# 25 Wins, 20 Draws, 25 Losses
# Scoring Percentage: 50.00%
# Total Games: 71
# 26 Wins, 20 Draws, 25 Losses
# Scoring Percentage: 50.70%
# Total Games: 72
# 26 Wins, 20 Draws, 26 Losses
# Scoring Percentage: 50.00%
# Total Games: 73
# 26 Wins, 20 Draws, 27 Losses
# Scoring Percentage: 49.32%
# Total Games: 74
# 27 Wins, 20 Draws, 27 Losses
# Scoring Percentage: 50.00%
# Total Games: 75
# 27 Wins, 20 Draws, 28 Losses
# Scoring Percentage: 49.33%
# Total Games: 76
# 28 Wins, 20 Draws, 28 Losses
# Scoring Percentage: 50.00%
# Total Games: 77
# 28 Wins, 20 Draws, 29 Losses
# Scoring Percentage: 49.35%
# Total Games: 78
# 29 Wins, 20 Draws, 29 Losses
# Scoring Percentage: 50.00%
# Total Games: 79
# 29 Wins, 20 Draws, 30 Losses
# Scoring Percentage: 49.37%
# Total Games: 80
# 30 Wins, 20 Draws, 30 Losses
# Scoring Percentage: 50.00%
# Total Games: 81
# 30 Wins, 20 Draws, 31 Losses
# Scoring Percentage: 49.38%
# Total Games: 82
# 30 Wins, 20 Draws, 32 Losses
# Scoring Percentage: 48.78%
# Total Games: 83
# 30 Wins, 21 Draws, 32 Losses
# Scoring Percentage: 48.80%
# Total Games: 84
# 30 Wins, 21 Draws, 33 Losses
# Scoring Percentage: 48.21%
# Total Games: 85
# 30 Wins, 21 Draws, 34 Losses
# Scoring Percentage: 47.65%
# Total Games: 86
# 30 Wins, 22 Draws, 34 Losses
# Scoring Percentage: 47.67%
# Total Games: 87
# 30 Wins, 22 Draws, 35 Losses
# Scoring Percentage: 47.13%
# Total Games: 88
# 30 Wins, 22 Draws, 36 Losses
# Scoring Percentage: 46.59%
# Total Games: 89
# 31 Wins, 22 Draws, 36 Losses
# Scoring Percentage: 47.19%
# Total Games: 90
# 31 Wins, 23 Draws, 36 Losses
# Scoring Percentage: 47.22%
# Total Games: 91
# 32 Wins, 23 Draws, 36 Losses
# Scoring Percentage: 47.80%
# Total Games: 92
# 32 Wins, 24 Draws, 36 Losses
# Scoring Percentage: 47.83%
# Total Games: 93
# 33 Wins, 24 Draws, 36 Losses
# Scoring Percentage: 48.39%
# Total Games: 94
# 33 Wins, 24 Draws, 37 Losses
# Scoring Percentage: 47.87%
# Total Games: 95
# 34 Wins, 24 Draws, 37 Losses
# Scoring Percentage: 48.42%
# Total Games: 96
# 34 Wins, 24 Draws, 38 Losses
# Scoring Percentage: 47.92%
# Total Games: 97
# 34 Wins, 25 Draws, 38 Losses
# Scoring Percentage: 47.94%
# Total Games: 98
# 34 Wins, 25 Draws, 39 Losses
# Scoring Percentage: 47.45%
# Total Games: 99
# 34 Wins, 25 Draws, 40 Losses
# Scoring Percentage: 46.97%
# Total Games: 100
# 34 Wins, 26 Draws, 40 Losses
# Scoring Percentage: 47.00%
# Total Games: 101
# 34 Wins, 27 Draws, 40 Losses
# Scoring Percentage: 47.03%
# Total Games: 102
# 35 Wins, 27 Draws, 40 Losses
# Scoring Percentage: 47.55%
# Total Games: 103
# 35 Wins, 28 Draws, 40 Losses
# Scoring Percentage: 47.57%
# Total Games: 104
# 35 Wins, 28 Draws, 41 Losses
# Scoring Percentage: 47.12%
# Total Games: 105
# 35 Wins, 28 Draws, 42 Losses
# Scoring Percentage: 46.67%
# Total Games: 106
# 35 Wins, 28 Draws, 43 Losses
# Scoring Percentage: 46.23%
# Total Games: 107
# 35 Wins, 28 Draws, 44 Losses
# Scoring Percentage: 45.79%
# Total Games: 108
# 35 Wins, 28 Draws, 45 Losses
# Scoring Percentage: 45.37%
# Total Games: 109
# 36 Wins, 28 Draws, 45 Losses
# Scoring Percentage: 45.87%
# Total Games: 110
# 36 Wins, 29 Draws, 45 Losses
# Scoring Percentage: 45.91%
# Total Games: 111
# 36 Wins, 29 Draws, 46 Losses
# Scoring Percentage: 45.50%
# Total Games: 112
# 36 Wins, 29 Draws, 47 Losses
# Scoring Percentage: 45.09%
# Total Games: 113
# 36 Wins, 29 Draws, 48 Losses
# Scoring Percentage: 44.69%
# Total Games: 114
# 36 Wins, 29 Draws, 49 Losses
# Scoring Percentage: 44.30%
# Total Games: 115
# 37 Wins, 29 Draws, 49 Losses
# Scoring Percentage: 44.78%
# Total Games: 116
# 37 Wins, 29 Draws, 50 Losses
# Scoring Percentage: 44.40%
# Total Games: 117
# 37 Wins, 30 Draws, 50 Losses
# Scoring Percentage: 44.44%
# Total Games: 118
# 37 Wins, 30 Draws, 51 Losses
# Scoring Percentage: 44.07%
# Total Games: 119
# 37 Wins, 31 Draws, 51 Losses
# Scoring Percentage: 44.12%
# Total Games: 120
# 38 Wins, 31 Draws, 51 Losses
# Scoring Percentage: 44.58%
# Total Games: 121
# 38 Wins, 31 Draws, 52 Losses
# Scoring Percentage: 44.21%
# Total Games: 122
# 38 Wins, 32 Draws, 52 Losses
# Scoring Percentage: 44.26%
# Total Games: 123
# 38 Wins, 32 Draws, 53 Losses
# Scoring Percentage: 43.90%
# Total Games: 124
# 38 Wins, 33 Draws, 53 Losses
# Scoring Percentage: 43.95%
# Total Games: 125
# 39 Wins, 33 Draws, 53 Losses
# Scoring Percentage: 44.40%
# Total Games: 126
# 40 Wins, 33 Draws, 53 Losses
# Scoring Percentage: 44.84%
# Total Games: 127
# 40 Wins, 33 Draws, 54 Losses
# Scoring Percentage: 44.49%
# Total Games: 128
# 41 Wins, 33 Draws, 54 Losses
# Scoring Percentage: 44.92%
# Total Games: 129
# 41 Wins, 34 Draws, 54 Losses
# Scoring Percentage: 44.96%
# Total Games: 130
# 41 Wins, 34 Draws, 55 Losses
# Scoring Percentage: 44.62%
# Total Games: 131
# 41 Wins, 35 Draws, 55 Losses
# Scoring Percentage: 44.66%
# Total Games: 132
# 41 Wins, 35 Draws, 56 Losses
# Scoring Percentage: 44.32%
# Total Games: 133
# 42 Wins, 35 Draws, 56 Losses
# Scoring Percentage: 44.74%
# Total Games: 134
# 42 Wins, 35 Draws, 57 Losses
# Scoring Percentage: 44.40%
# Total Games: 135
# 42 Wins, 36 Draws, 57 Losses
# Scoring Percentage: 44.44%
# Total Games: 136
# 43 Wins, 36 Draws, 57 Losses
# Scoring Percentage: 44.85%
# Total Games: 137
# 43 Wins, 36 Draws, 58 Losses
# Scoring Percentage: 44.53%
# Total Games: 138
# 43 Wins, 37 Draws, 58 Losses
# Scoring Percentage: 44.57%
# Total Games: 139
# 43 Wins, 37 Draws, 59 Losses
# Scoring Percentage: 44.24%
# Total Games: 140
# 43 Wins, 37 Draws, 60 Losses
# Scoring Percentage: 43.93%
# Total Games: 141
# 44 Wins, 37 Draws, 60 Losses
# Scoring Percentage: 44.33%
# Total Games: 142
# 44 Wins, 37 Draws, 61 Losses
# Scoring Percentage: 44.01%
# Total Games: 143
# 44 Wins, 37 Draws, 62 Losses
# Scoring Percentage: 43.71%
# Total Games: 144
# 44 Wins, 37 Draws, 63 Losses
# Scoring Percentage: 43.40%
# Total Games: 145
# 44 Wins, 37 Draws, 64 Losses
# Scoring Percentage: 43.10%
# Total Games: 146
# 44 Wins, 37 Draws, 65 Losses
# Scoring Percentage: 42.81%
# Total Games: 147
# 44 Wins, 37 Draws, 66 Losses
# Scoring Percentage: 42.52%
# Total Games: 148
# 44 Wins, 37 Draws, 67 Losses
# Scoring Percentage: 42.23%
# Total Games: 149
# 45 Wins, 37 Draws, 67 Losses
# Scoring Percentage: 42.62%
# Total Games: 150
# 45 Wins, 37 Draws, 68 Losses
# Scoring Percentage: 42.33%
# Total Games: 151
# 45 Wins, 38 Draws, 68 Losses
# Scoring Percentage: 42.38%
# Total Games: 152
# 45 Wins, 38 Draws, 69 Losses
# Scoring Percentage: 42.11%
# Total Games: 153
# 45 Wins, 38 Draws, 70 Losses
# Scoring Percentage: 41.83%
# Total Games: 154
# 46 Wins, 38 Draws, 70 Losses
# Scoring Percentage: 42.21%
# Total Games: 155
# 46 Wins, 38 Draws, 71 Losses
# Scoring Percentage: 41.94%
# Total Games: 156
# 47 Wins, 38 Draws, 71 Losses
# Scoring Percentage: 42.31%
# Total Games: 157
# 47 Wins, 38 Draws, 72 Losses
# Scoring Percentage: 42.04%
# Total Games: 158
# 47 Wins, 39 Draws, 72 Losses
# Scoring Percentage: 42.09%
# Total Games: 159
# 47 Wins, 39 Draws, 73 Losses
# Scoring Percentage: 41.82%
# Total Games: 160
# 48 Wins, 39 Draws, 73 Losses
# Scoring Percentage: 42.19%
# Total Games: 161
# 48 Wins, 39 Draws, 74 Losses
# Scoring Percentage: 41.93%
# Total Games: 162
# 48 Wins, 40 Draws, 74 Losses
# Scoring Percentage: 41.98%
# Total Games: 163
# 49 Wins, 40 Draws, 74 Losses
# Scoring Percentage: 42.33%
# Total Games: 164
# 49 Wins, 40 Draws, 75 Losses
# Scoring Percentage: 42.07%
# Total Games: 165
# 49 Wins, 40 Draws, 76 Losses
# Scoring Percentage: 41.82%
# Total Games: 166
# 49 Wins, 40 Draws, 77 Losses
# Scoring Percentage: 41.57%
# Total Games: 167
# 49 Wins, 40 Draws, 78 Losses
# Scoring Percentage: 41.32%
# Total Games: 168
# 49 Wins, 40 Draws, 79 Losses
# Scoring Percentage: 41.07%
# Total Games: 169
# 49 Wins, 40 Draws, 80 Losses
# Scoring Percentage: 40.83%
# Total Games: 170
# 49 Wins, 40 Draws, 81 Losses
# Scoring Percentage: 40.59%
# Total Games: 171
# 49 Wins, 41 Draws, 81 Losses
# Scoring Percentage: 40.64%
# Total Games: 172
# 49 Wins, 42 Draws, 81 Losses
# Scoring Percentage: 40.70%
# Total Games: 173
# 49 Wins, 42 Draws, 82 Losses
# Scoring Percentage: 40.46%
# Total Games: 174
# 49 Wins, 43 Draws, 82 Losses
# Scoring Percentage: 40.52%
# Total Games: 175
# 49 Wins, 43 Draws, 83 Losses
# Scoring Percentage: 40.29%
# Total Games: 176
# 49 Wins, 44 Draws, 83 Losses
# Scoring Percentage: 40.34%
# Total Games: 177
# 49 Wins, 44 Draws, 84 Losses
# Scoring Percentage: 40.11%
# Total Games: 178
# 49 Wins, 44 Draws, 85 Losses
# Scoring Percentage: 39.89%
# Total Games: 179
# 49 Wins, 45 Draws, 85 Losses
# Scoring Percentage: 39.94%
# Total Games: 180
# 49 Wins, 45 Draws, 86 Losses
# Scoring Percentage: 39.72%
# Total Games: 181
# 49 Wins, 45 Draws, 87 Losses
# Scoring Percentage: 39.50%
# Total Games: 182
# 49 Wins, 46 Draws, 87 Losses
# Scoring Percentage: 39.56%
# Total Games: 183
# 49 Wins, 46 Draws, 88 Losses
# Scoring Percentage: 39.34%
# Total Games: 184
# 49 Wins, 46 Draws, 89 Losses
# Scoring Percentage: 39.13%
# Total Games: 185
# 49 Wins, 46 Draws, 90 Losses
# Scoring Percentage: 38.92%
# Total Games: 186
# 49 Wins, 46 Draws, 91 Losses
# Scoring Percentage: 38.71%
# Total Games: 187
# 49 Wins, 46 Draws, 92 Losses
# Scoring Percentage: 38.50%
# Total Games: 188
# 50 Wins, 46 Draws, 92 Losses
# Scoring Percentage: 38.83%
# Total Games: 189
# 50 Wins, 46 Draws, 93 Losses
# Scoring Percentage: 38.62%
# Total Games: 190
# 51 Wins, 46 Draws, 93 Losses
# Scoring Percentage: 38.95%
# Total Games: 191
# 51 Wins, 46 Draws, 94 Losses
# Scoring Percentage: 38.74%
# Total Games: 192
# 51 Wins, 46 Draws, 95 Losses
# Scoring Percentage: 38.54%
# Total Games: 193
# 51 Wins, 47 Draws, 95 Losses
# Scoring Percentage: 38.60%
# Total Games: 194
# 51 Wins, 47 Draws, 96 Losses
# Scoring Percentage: 38.40%
# Total Games: 195
# 51 Wins, 48 Draws, 96 Losses
# Scoring Percentage: 38.46%
# Total Games: 196
# 51 Wins, 48 Draws, 97 Losses
# Scoring Percentage: 38.27%
# Total Games: 197
# 51 Wins, 48 Draws, 98 Losses
# Scoring Percentage: 38.07%
# Total Games: 198
# 51 Wins, 48 Draws, 99 Losses
# Scoring Percentage: 37.88%
# Total Games: 199
# 51 Wins, 49 Draws, 99 Losses
# Scoring Percentage: 37.94%
# Total Games: 200
# 51 Wins, 49 Draws, 100 Losses
# Scoring Percentage: 37.75%
# Total Games: 201
# 51 Wins, 50 Draws, 100 Losses
# Scoring Percentage: 37.81%
# Total Games: 202
# 51 Wins, 50 Draws, 101 Losses
# Scoring Percentage: 37.62%
# Total Games: 203
# 51 Wins, 50 Draws, 102 Losses
# Scoring Percentage: 37.44%
# Total Games: 204
# 51 Wins, 51 Draws, 102 Losses
# Scoring Percentage: 37.50%
# Total Games: 205
# 51 Wins, 52 Draws, 102 Losses
# Scoring Percentage: 37.56%
# Total Games: 206
# 52 Wins, 52 Draws, 102 Losses
# Scoring Percentage: 37.86%
# Total Games: 207
# 53 Wins, 52 Draws, 102 Losses
# Scoring Percentage: 38.16%
# Total Games: 208
# 53 Wins, 52 Draws, 103 Losses
# Scoring Percentage: 37.98%
# Total Games: 209
# 53 Wins, 52 Draws, 104 Losses
# Scoring Percentage: 37.80%
# Total Games: 210
# 53 Wins, 52 Draws, 105 Losses
# Scoring Percentage: 37.62%
# Total Games: 211
# 53 Wins, 52 Draws, 106 Losses
# Scoring Percentage: 37.44%
# Total Games: 212
# 54 Wins, 52 Draws, 106 Losses
# Scoring Percentage: 37.74%
# Total Games: 213
# 54 Wins, 52 Draws, 107 Losses
# Scoring Percentage: 37.56%
# Total Games: 214
# 54 Wins, 52 Draws, 108 Losses
# Scoring Percentage: 37.38%
# Total Games: 215
# 54 Wins, 52 Draws, 109 Losses
# Scoring Percentage: 37.21%
# Total Games: 216
# 54 Wins, 52 Draws, 110 Losses
# Scoring Percentage: 37.04%
# Total Games: 217
# 54 Wins, 52 Draws, 111 Losses
# Scoring Percentage: 36.87%
# Total Games: 218
# 54 Wins, 52 Draws, 112 Losses
# Scoring Percentage: 36.70%
# Total Games: 219
# 55 Wins, 52 Draws, 112 Losses
# Scoring Percentage: 36.99%
# Total Games: 220
# 55 Wins, 52 Draws, 113 Losses
# Scoring Percentage: 36.82%
# Total Games: 221
# 55 Wins, 53 Draws, 113 Losses
# Scoring Percentage: 36.88%
# Total Games: 222
# 55 Wins, 54 Draws, 113 Losses
# Scoring Percentage: 36.94%
# Total Games: 223
# 55 Wins, 54 Draws, 114 Losses
# Scoring Percentage: 36.77%
# Total Games: 224
# 55 Wins, 54 Draws, 115 Losses
# Scoring Percentage: 36.61%
# Total Games: 225
# 56 Wins, 54 Draws, 115 Losses
# Scoring Percentage: 36.89%
# Total Games: 226
# 56 Wins, 54 Draws, 116 Losses
# Scoring Percentage: 36.73%
# Total Games: 227
# 56 Wins, 55 Draws, 116 Losses
# Scoring Percentage: 36.78%
# Total Games: 228
# 56 Wins, 55 Draws, 117 Losses
# Scoring Percentage: 36.62%
# Total Games: 229
# 56 Wins, 55 Draws, 118 Losses
# Scoring Percentage: 36.46%
# Total Games: 230
# 56 Wins, 55 Draws, 119 Losses
# Scoring Percentage: 36.30%
# Total Games: 231
# 57 Wins, 55 Draws, 119 Losses
# Scoring Percentage: 36.58%
# Total Games: 232
# 57 Wins, 55 Draws, 120 Losses
# Scoring Percentage: 36.42%
# Total Games: 233
# 57 Wins, 56 Draws, 120 Losses
# Scoring Percentage: 36.48%
# Total Games: 234
# 57 Wins, 56 Draws, 121 Losses
# Scoring Percentage: 36.32%
# Total Games: 235
# 57 Wins, 56 Draws, 122 Losses
# Scoring Percentage: 36.17%
# Total Games: 236
# 57 Wins, 56 Draws, 123 Losses
# Scoring Percentage: 36.02%
# Total Games: 237
# 57 Wins, 57 Draws, 123 Losses
# Scoring Percentage: 36.08%
# Total Games: 238
# 57 Wins, 57 Draws, 124 Losses
# Scoring Percentage: 35.92%
# Total Games: 239
# 57 Wins, 57 Draws, 125 Losses
# Scoring Percentage: 35.77%
# Total Games: 240
# 57 Wins, 57 Draws, 126 Losses
# Scoring Percentage: 35.62%
# Total Games: 241
# 57 Wins, 58 Draws, 126 Losses
# Scoring Percentage: 35.68%
# Total Games: 242
# 57 Wins, 59 Draws, 126 Losses
# Scoring Percentage: 35.74%
# Total Games: 243
# 57 Wins, 60 Draws, 126 Losses
# Scoring Percentage: 35.80%
# Total Games: 244
# 57 Wins, 60 Draws, 127 Losses
# Scoring Percentage: 35.66%
# Total Games: 245
# 57 Wins, 60 Draws, 128 Losses
# Scoring Percentage: 35.51%
# Total Games: 246
# 57 Wins, 60 Draws, 129 Losses
# Scoring Percentage: 35.37%
# Total Games: 247
# 58 Wins, 60 Draws, 129 Losses
# Scoring Percentage: 35.63%
# Total Games: 248
# 59 Wins, 60 Draws, 129 Losses
# Scoring Percentage: 35.89%
# Total Games: 249
# 60 Wins, 60 Draws, 129 Losses
# Scoring Percentage: 36.14%
# Total Games: 250
# 61 Wins, 60 Draws, 129 Losses
# Scoring Percentage: 36.40%
